# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('../input/farmers-suicide/Survey on Farmers suicide in India.csv')
df.tail()
df.info()
df

# %%
genders = ['Male', 'Female']
cnt=df['gender_commits_more_suicide'].value_counts()
#df1= df['gender_commits_more_suicide']
fig = plt.figure(figsize =(10, 7))
plt.pie(cnt, labels = genders)
plt.legend(title = "Gender Committing highest Suicide")
  
# show plot
plt.show()
#plt.pie(x='gender_commits_more_suicide', hue="gender_commits_more_suicide", data=df,order=['Female','Male'])
#plt.xlabel('Gender')
#plt.ylabel('Count')
#plt.title('Gender Wise Count')
#for p in ax.patches:
 #       ax.annotate('%{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))

# %%
sns.countplot(x='age-group_committing_highest_suicide', hue="age-group_committing_highest_suicide", data=df)
plt.xlabel('Age-Group')
plt.ylabel('Count')
plt.title('Age-Group Wise Count')
for p in ax.patches:
        ax.annotate('%{:.1f}'.format(p.get_height()), (p.get_x()+0.1,p.get_height()+50))
plt.show()

# %%
sns.countplot(x='education', hue="education", data=df)
plt.xlabel('Education level')
plt.ylabel('Count')
plt.title('Education level Wise Count')
for p in ax.patches:
        ax.annotate('%{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))

# %%
sns.countplot(x='martial_status', hue="martial_status", data=df)
plt.xlabel('Education level')
plt.ylabel('Count')
plt.title('Marital Status Wise Count')
for p in ax.patches:
        ax.annotate('%{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))
plt.show()

# %%
ax=sns.countplot(x='method_opted_by_males', hue="method_opted_by_males", data=df)
plt.xlabel('Education level')
plt.ylabel('Count')
plt.title('Method opted by males Wise Count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
ax=sns.countplot(x='method_opted_by_females', hue="method_opted_by_females", data=df)
plt.xlabel('Education level')
plt.ylabel('Count')
plt.title('Method opted by females Wise Count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
ax=sns.countplot(x='cause_for_male', hue="cause_for_male", data=df)
plt.xlabel('Education level')
plt.ylabel('Count')
plt.title('Cause for males Count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
ax=sns.countplot(x='cause_for_female', hue="cause_for_female", data=df)
plt.xlabel('Education level')
plt.ylabel('Count')
plt.title('Cause for Females Wise Count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
df1 = df[['gender_commits_more_suicide','age-group_committing_highest_suicide']]
sns.countplot(x='age-group_committing_highest_suicide',hue='gender_commits_more_suicide',data=df1,palette='RdBu')

# %%
df1 = df[['gender_commits_more_suicide','education']]
sns.countplot(x='education',hue='gender_commits_more_suicide',data=df1,palette='RdBu')

# %%
df1 = df[['gender_commits_more_suicide','martial_status']]
sns.countplot(x='martial_status',hue='gender_commits_more_suicide',data=df1,palette='RdBu')

# %%
df1 = df[['gender_commits_more_suicide_in_karnataka','age-group_committing_highest_suicide_in_karnataka']]
sns.countplot(x='age-group_committing_highest_suicide_in_karnataka',hue='gender_commits_more_suicide_in_karnataka',data=df1,palette='RdBu')

# %%
df1 = df[['gender_commits_more_suicide_in_odisha','age-group_committing_highest_suicide_in_odisha']]
sns.countplot(x='age-group_committing_highest_suicide_in_odisha',hue='gender_commits_more_suicide_in_odisha',data=df1,palette='RdBu')

# %%
df1 = df[['gender_commits_more_suicide_in_karnataka','education_status_in_karnataka']]
sns.countplot(x='education_status_in_karnataka',hue='gender_commits_more_suicide_in_karnataka',data=df1,palette='RdBu')

# %%
df1 = df[['age-group_committing_highest_suicide_in_karnataka','education_status_in_karnataka']]
sns.countplot(x='age-group_committing_highest_suicide_in_karnataka',hue='education_status_in_karnataka',data=df1,palette='RdBu')

# %%
df1 = df[['age-group_committing_highest_suicide_in_karnataka','method_opted_in_karnataka']]
sns.countplot(x='age-group_committing_highest_suicide_in_karnataka',hue='method_opted_in_karnataka',data=df1,palette='RdBu')

# %%
sns.countplot(x='reason_in_karnataka',data=df,palette='RdBu')

# %%
df1 = df[['reason_in_karnataka','gender_commits_more_suicide_in_karnataka']]
sns.countplot(x='reason_in_karnataka',hue='gender_commits_more_suicide_in_karnataka',data=df1,palette='RdBu')

# %%
ax = sns.countplot(x='method_opted_by_1-14',data=df,palette='RdBu')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
ax = sns.countplot(x='method_opted_by_15-29',data=df,palette='RdBu')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
ax = sns.countplot(x='method_opted_by_30-44',data=df,palette='RdBu')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
ax =sns.countplot(x='method_opted_by_45-59',data=df,palette='RdBu')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
ax = sns.countplot(x='method_opted_by_60+',data=df,palette='RdBu')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
